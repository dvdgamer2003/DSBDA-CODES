# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag
from sklearn.feature_extraction.text import TfidfVectorizer



nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\divye\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\divye\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\divye\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\divye\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\divye\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\divye\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = "I am learning Data Analytics and it is very interesting"
print("Original Text:", text)
# Out:
# Original Text: I am learning Data Analytics and it is very interesting

# %%
tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# Tokens: ['I', 'am', 'learning', 'Data', 'Analytics', 'and', 'it', 'is', 'very', 'interesting']

# %%
pos = pos_tag(tokens)
print("POS Tags:", pos)
# Out:
# POS Tags: [('I', 'PRP'), ('am', 'VBP'), ('learning', 'VBG'), ('Data', 'NNP'), ('Analytics', 'NNPS'), ('and', 'CC'), ('it', 'PRP'), ('is', 'VBZ'), ('very', 'RB'), ('interesting', 'JJ')]

# %%
stop_words = set(stopwords.words('english'))

filtered = [w for w in tokens if w.lower() not in stop_words]
print("After Stopword Removal:", filtered)
# Out:
# After Stopword Removal: ['learning', 'Data', 'Analytics', 'interesting']

# %%
ps = PorterStemmer()

stemmed = [ps.stem(w) for w in filtered]
print("Stemmed Words:", stemmed)
# Out:
# Stemmed Words: ['learn', 'data', 'analyt', 'interest']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized = [lemmatizer.lemmatize(w) for w in filtered]
print("Lemmatized Words:", lemmatized)
# Out:
# Lemmatized Words: ['learning', 'Data', 'Analytics', 'interesting']

# %%
docs = [
    "I love data science",
    "Data analytics is powerful"
]

vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(docs)

print("Feature Names:", vectorizer.get_feature_names_out())
print("TF-IDF Matrix:\n", tfidf.toarray())
# Out:
# Feature Names: ['analytics' 'data' 'is' 'love' 'powerful' 'science']
# TF-IDF Matrix:
#  [[0.         0.44943642 0.         0.6316672  0.         0.6316672 ]
#  [0.53404633 0.37997836 0.53404633 0.         0.53404633 0.        ]]
